# %% [markdown]
# # EDA

# %%
# Import the liraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## data_by_artist

# %%
# Load the data
data_by_artist = pd.read_csv("../data/data_by_artist.csv")

# Preview the data
data_by_artist.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# ...

# %%
# Top 10 Most Popular Artists
data_by_artist.sort_values("popularity", ascending = False).head(10)
# Out:
#        mode  count  acousticness          artists  danceability  duration_ms  \
# 20966     0      2      0.056300      Ritt Momney      0.399000     210463.0
# 14354     1      1      0.090700        Lele Pons      0.905000     155825.0
# 15070     0      2      0.310000  Los Legendarios      0.823000     213314.0
# 11764     1      2      0.819000         Jerry Di      0.854000     197587.0
# 28263     1      2      0.424000      salem ilese      0.738000     136839.0
# 23687     0      1      0.068600        Surf Mesa      0.674000     176547.0
# 7463      0      2      0.068600           Emilee      0.674000     176547.0
# 213       0      3      0.166633              A7S      0.742667     168293.0
# 26318     0      1      0.111000             Towy      0.863000     260545.0
# 16453     1      1      0.018500        Master KG      0.880000     342613.0
#
#        energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# ...

# %%
# Load the data
data_by_genres = pd.read_csv("../data/data_by_genres.csv")

# Preview the data
data_by_genres.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
# Top 10 Most Popular Genres
data_by_genres.sort_values("popularity", ascending = False).head(10)
# Out:
#       mode               genres  acousticness  danceability    duration_ms  \
# 237      1             basshall      0.213167       0.81800  169799.166667
# 2778     0          turkish edm      0.008290       0.69800  186700.000000
# 2533     1  south african house      0.043833       0.84700  311854.333333
# 2755     1      trap venezolano      0.044600       0.87700  231848.000000
# 46       0      alberta hip hop      0.330000       0.88500  144000.000000
# 536      0   chinese electropop      0.002570       0.66000  217088.000000
# 37       0            afroswing      0.318450       0.71175  179995.375000
# 31       0            afro soul      0.006270       0.76600  202627.000000
# 2383     1        russian dance      0.005610       0.65300  198095.000000
# 1239     1             guaracha      0.009030       0.74500  189818.000000
#
#         energy  instrumentalness  liveness  loudness  speechiness       tempo  \
# ...

# %% [markdown]
# ___

# %%
# Load the data
spotify_data = pd.read_csv("../data/spotify_data.csv")

# Preview the data
spotify_data.head()
# Out:
#                   song_id                                          song_name  \
# 0  4BJqT0PrAfrxzMOxytFOIz  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1  7xPhfUan2yNtyFG0cUWkt8                            Clancy Lowered the Boom
# 2  1o6I8BglA6ylDMrIELygv1                                          Gati Bali
# 3  3ftBPsC5vPBKxYSee08FDH                                          Danny Boy
# 4  4d6HGyGT8e121BsdKmw9v6                        When Irish Eyes Are Smiling
#
#     artist_id                                        artist_name  year  \
# 0  9b149f96aa                                Sergei Rachmaninoff  1921
# 1  9d8adf100a                                         Dennis Day  1921
# 2  466b918be0  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...  1921
# 3  a8250f99cc                                       Frank Parker  1921
# 4  c2a61e6015                                         Phil Regan  1921
#
#   release_date  valence  acousticness  danceability  duration_ms  ...  \
# ...

# %%
# Top 10 Most Popular Songs Over Time
spotify_data.sort_values("popularity", ascending = False).head(10)
# Out:
#                       song_id                                song_name  \
# 19611  47EiUVwUp4C9fGccaPuUCS                                   Dakiti
# 19606  3tjFYV6RSFtuktYl3ZtYcq                   Mood (feat. iann dior)
# 19618  0t1kP63rueHleOhQkYSXFY                                 Dynamite
# 19608  4Oun2ylbjFKMPTiaSbbCih          WAP (feat. Megan Thee Stallion)
# 19610  35mvY5S1H3J2QZyna3TFe0                                positions
# 19612  1tkg4EHVoqnhR6iFEXb60y                  What You Know Bout Love
# 19616  0VjIjW4GlUZAMYd2vXMi3b                          Blinding Lights
# 19607  0PvFJmanyNQMseIFrU708S  For The Night (feat. Lil Baby & DaBaby)
# 19615  5u1n1kITHCxxp8twBcZxWy           Holy (feat. Chance The Rapper)
# 19620  4y4spB9m0Q6026KfkAvy9Q               Lonely (with benny blanco)
#
#         artist_id    artist_name  year release_date  valence  acousticness  \
# 19611  0f48377175      Bad Bunny  2020   2020-10-30   0.1450       0.40100
# ...
