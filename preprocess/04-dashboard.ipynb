# %% [markdown]
# # User Dashboard

# %%
# Import the liraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load the data
spotify_data = pd.read_csv("../data/spotify_data.csv")

# Preview the data
spotify_data.head()
# Out:
#                   song_id                                          song_name  \
# 0  4BJqT0PrAfrxzMOxytFOIz  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1  7xPhfUan2yNtyFG0cUWkt8                            Clancy Lowered the Boom
# 2  1o6I8BglA6ylDMrIELygv1                                          Gati Bali
# 3  3ftBPsC5vPBKxYSee08FDH                                          Danny Boy
# 4  4d6HGyGT8e121BsdKmw9v6                        When Irish Eyes Are Smiling
#
#     artist_id                                        artist_name  year  \
# 0  9b149f96aa                                Sergei Rachmaninoff  1921
# 1  9d8adf100a                                         Dennis Day  1921
# 2  466b918be0  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...  1921
# 3  a8250f99cc                                       Frank Parker  1921
# 4  c2a61e6015                                         Phil Regan  1921
#
#   release_date  valence  acousticness  danceability  duration_ms  ...  \
# 0         1921   0.0594         0.982         0.279       831667  ...
# 1         1921   0.9630         0.732         0.819       180533  ...
# 2         1921   0.0394         0.961         0.328       500062  ...
# 3         1921   0.1650         0.967         0.275       210000  ...
# 4         1921   0.2530         0.957         0.418       166693  ...
#
#    explicit  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0         0          0.878000   10     0.665   -20.096     1       0.0366
# 1         0          0.000000    7     0.160   -12.441     1       0.4150
# 2         0          0.913000    3     0.101   -14.850     1       0.0339
# 3         0          0.000028    5     0.381    -9.316     1       0.0354
# 4         0          0.000002    3     0.229   -10.096     1       0.0380
#
#      tempo                                              genre popularity
# 0   80.954  classical, post-romantic era, russian romantic...          4
# 1   60.936                                            Unknown          5
# 2  110.339                                            Unknown          5
# 3  100.109                                            Unknown          3
# 4  101.665                                            Unknown          2
#
# [5 rows x 21 columns]

# %%
# Load the data
user_songs = pd.read_csv("../data/user_songs.csv")

# Preview the data
user_songs.head()
# Out:
#    id                               user_id                 song_id  \
# 0   1  baefc413-5ca5-40d4-b85e-000e2e80a003  0h083GWZ2W5scJM6JgwETQ
# 1   2  4da237ee-f206-4a74-866b-04c3c19ecef0  3QWlqqpc4EOm52xipzSehQ
# 2   3  9f10a3cb-6cd2-4d0a-8318-8f7eba13ec05  174BJkBMuLak3wSvYHASpo
# 3   4  b71a3b34-0f5f-4018-af95-95ccdb1a1bf9  0LCgPftb1BoxaAmKe8RwY8
# 4   5  5a5631d5-fdd6-461c-9f06-72de9fb76062  2WinyCfKidqagBGRVPtsTR
#
#    listening_count
# 0                3
# 1                3
# 2                9
# 3                1
# 4               27

# %%
# Filter the user_songs dataframe for the specific user_id
user_id = "19678c5c-9d86-4c9e-a0e4-4fa173a8bb5a"
filtered_user_songs = user_songs[user_songs['user_id'] == user_id]

# Inner join the data frames on song_id
joined_df = pd.merge(filtered_user_songs, spotify_data, on = "song_id", how = "inner")

# Select the required columns
selected_columns = [
    "song_id", "listening_count", "song_name", "artist_name", "year", 
    "valence", "acousticness", "danceability", "energy", "instrumentalness", 
    "liveness", "speechiness"
]
result_df = joined_df[selected_columns]

result_df.head()  # Display the first few rows of the result dataframe
# Out:
#                   song_id  listening_count             song_name  \
# 0  2GUHoCeXGlu7xvmUJJEav6              113       Vasilarxontissa
# 1  4GGvLe0rAVoqGIg7aZnxBC                3       Graveyard Shift
# 2  0WSPIU3Y3bNXsGeKnzSnt1              233             warm glow
# 3  1gsmW1lxAbupMfOEKjG0l4                6      Ring for Freedom
# 4  0bVjq1ftiCMCKiXIO3JEiX                6  Casual Conversations
#
#          artist_name  year  valence  acousticness  danceability  energy  \
# 0  Dimitris Arapakis  1940   0.5440      0.987000        0.3570   0.496
# 1       Uncle Tupelo  1990   0.6590      0.000972        0.3720   0.827
# 2       Hippo Campus  2017   0.0384      0.324000        0.4450   0.446
# 3       Miklós Rózsa  1960   0.0724      0.785000        0.0965   0.183
# 4         Supertramp  1979   0.4450      0.570000        0.6230   0.220
#
#    instrumentalness  liveness  speechiness
# 0           0.03290    0.3990       0.0446
# 1           0.30800    0.4060       0.0472
# 2           0.11900    0.1060       0.0286
# 3           0.75200    0.1170       0.0389
# 4           0.00102    0.0819       0.0294

# %%
import numpy as np

# Extracting the columns for the weighted average calculation
attributes = ["valence", "acousticness", "danceability", "energy", "instrumentalness", "liveness", "speechiness"]
weights = result_df["listening_count"].values

# Calculating the weighted average for each attribute
weighted_averages = {}
for attribute in attributes:
    values = result_df[attribute].values
    weighted_average = np.sum(values * weights) / np.sum(weights)
    weighted_averages[attribute] = weighted_average

# Creating a DataFrame for the result
weighted_averages_df = pd.DataFrame(weighted_averages, index=[0])
weighted_averages_df
# Out:
#     valence  acousticness  danceability   energy  instrumentalness  liveness  \
# 0  0.209143      0.540598      0.414014  0.45669           0.10218   0.19999
#
#    speechiness
# 0     0.033947
