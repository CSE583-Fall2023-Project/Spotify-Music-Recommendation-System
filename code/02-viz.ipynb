# %% [markdown]
# # Visualizations

# %%
# Import the liraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load the data
data_by_year = pd.read_csv("../data/data_by_year.csv")

# Preview the data
data_by_year.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# ...

# %%
# Trend of musical features over years
attr = ["acousticness", "danceability", "energy", "instrumentalness", 
        "liveness", "speechiness", "valence"]
fig = px.line(data_by_year, x = "year", y = attr, 
              title = "Trend of Musical Features Over Time")
fig.update_layout(
    plot_bgcolor = "#121212",    
    paper_bgcolor = "#121212",   
    font = dict(family = "Gill Sans, Arial, sans-serif", 
                color = "#f2f2f2"), 
    title = dict(x = 0.5)
)

# %%
# Trend of musical features over years
fig = px.line(data_by_year, x = "year", y = "duration_ms", 
              title = "Trend of Duration Over Time")
fig.update_layout(
    plot_bgcolor = "#121212",    
    paper_bgcolor = "#121212",   
    font = dict(family = "Gill Sans, Arial, sans-serif", 
                color = "#f2f2f2"), 
    title = dict(x = 0.5)
)

# %%
# Trend of musical features over years
fig = px.line(data_by_year, x = "year", y = "loudness", 
              title = "Trend of Loudness Over Time")
fig.update_layout(
    plot_bgcolor = "#121212",    
    paper_bgcolor = "#121212",   
    font = dict(family = "Gill Sans, Arial, sans-serif", 
                color = "#f2f2f2"), 
    title = dict(x = 0.5)
)

# %%
# Trend of musical features over years
fig = px.line(data_by_year, x = "year", y = "tempo", 
              title = "Trend of Tempo Over Time")
fig.update_layout(
    plot_bgcolor = "#121212",    
    paper_bgcolor = "#121212",   
    font = dict(family = "Gill Sans, Arial, sans-serif", 
                color = "#f2f2f2"), 
    title = dict(x = 0.5)
)

# %%
# Trend of musical features over years
fig = px.line(data_by_year, x = "year", y = "popularity", 
              title = "Trend of Popularity Over Time")
fig.update_layout(
    plot_bgcolor = "#121212",    
    paper_bgcolor = "#121212",   
    font = dict(family = "Gill Sans, Arial, sans-serif", 
                color = "#f2f2f2"), 
    title = dict(x = 0.5)
)

# %% [markdown]
# ___
